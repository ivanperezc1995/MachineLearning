# %% [markdown]
# ## No Lineal Regression

# %% [markdown]
# Cuando los datos presentan tendencias curvas, no podemos usar la regresión lineal ya que no produciria resultados muy exactos cuando se comparan con una regresión no lineal

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import urllib.request

# %%
#Creamos array de numeros del -5 al 5 de.1 en .1
x = np.arange(-5.0, 5.0, 0.1)

y=2*(x)+3
y_noise=2*np.random.normal(size=x.size)
ydata=y+y_noise

plt.figure(figsize=(8,6))
plt.plot(x,ydata,"bo")
plt.plot(x,y,"r")
plt.xlabel('Variable dependiente')
plt.ylabel('Variable independiente')
# Out:
# Text(0, 0.5, 'Variable independiente')

# %%
x = np.arange(-5.0, 5.0, 0.1)

##Se puede ajustar la pendiente y la intersección para verificar los cambios en el gráfico

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable indepdiendente')
plt.show()

# %%
X = np.arange(-5.0, 5.0, 0.1)

##Se puede ajustar la pendiente y la intersección para verificar los cambios en el gráfico

Y= np.exp(X)

plt.plot(X,Y) 
plt.ylabel('Variable Dependiente')
plt.xlabel('Variable Independiente')
plt.show()

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Variable Dependiente')
plt.xlabel('Variable Independiente')
plt.show()
# Out:
# <ipython-input-12-225a23f8f1eb>:3: RuntimeWarning: invalid value encountered in log
#   Y = np.log(X)

# %%
X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Variable Dependiente')
plt.xlabel('Variable Independiente')
plt.show()

# %%
url = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/china_gdp.csv'
filename = 'china_gdp.csv'
urllib.request.urlretrieve(url, filename)
# Out:
# ('china_gdp.csv', <http.client.HTTPMessage at 0x267d29ec5e0>)

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("china_gdp.csv")
df.head(10)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10
