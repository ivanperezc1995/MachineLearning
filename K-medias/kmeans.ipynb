# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("wine-quality-white-and-red.csv", index_col=0)
df.head()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# type
# white            7.0              0.27         0.36            20.7
# white            6.3              0.30         0.34             1.6
# white            8.1              0.28         0.40             6.9
# white            7.2              0.23         0.32             8.5
# white            7.2              0.23         0.32             8.5
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# type
# white      0.045                 45.0                 170.0   1.0010  3.00
# white      0.049                 14.0                 132.0   0.9940  3.30
# white      0.050                 30.0                  97.0   0.9951  3.26
# white      0.058                 47.0                 186.0   0.9956  3.19
# white      0.058                 47.0                 186.0   0.9956  3.19
#
#        sulphates  alcohol  quality
# type
# white       0.45      8.8        6
# white       0.49      9.5        6
# white       0.44     10.1        6
# white       0.40      9.9        6
# white       0.40      9.9        6

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
#
#                        alcohol   quality
# fixed acidity        -0.095452 -0.076743
# volatile acidity     -0.037640 -0.265699
# citric acid          -0.010493  0.085532
# residual sugar       -0.359415 -0.036980
# chlorides            -0.256916 -0.200666
# free sulfur dioxide  -0.179838  0.055463
# total sulfur dioxide -0.265740 -0.041385
# density              -0.686745 -0.305858
# pH                    0.121248  0.019506
# sulphates            -0.003029  0.038485
# alcohol               1.000000  0.444319
# quality               0.444319  1.000000

# %%
plt.figure(figsize=(8,6))
ax=sns.heatmap(df.corr(),vmin=-1,vmax=1,annot=True,cmap="YlGnBu",linewidths=.5)

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot()

ax.set_title('Ubicación de crímenes', pad=15)
ax.set_xlabel('alcohol')
ax.set_ylabel('fixed acidity')

sns.scatterplot(df['alcohol'], df['fixed acidity'], ax=ax);
# Out:
# C:\Users\ivanp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans

# %%
k_means=KMeans(n_clusters=10,max_iter=2000)

# %%
k_means.fit(df[["alcohol","fixed acidity"]])
# Out:
# KMeans(max_iter=2000, n_clusters=10)

# %%
centers=k_means.cluster_centers_
centers
# Out:
# array([[10.98103387,  6.0427139 ],
#        [ 9.73096447,  8.41692047],
#        [ 9.31916667,  7.27034483],
#        [12.75010417,  5.706875  ],
#        [10.76387087,  7.16876738],
#        [10.33931034, 10.03103448],
#        [11.79633419,  8.3629156 ],
#        [ 9.48462631,  6.3140665 ],
#        [10.51469816, 12.33307087],
#        [12.33710895,  6.85598706]])

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_subplot()

ax.set_title('Calidad de vinos por cantidad de alcohol  y acides', pad=15)
ax.set_xlabel('Alcohol')
ax.set_ylabel('fixed acidity')

sns.scatterplot(df['alcohol'], df['fixed acidity'], ax=ax, palette='rainbow');
sns.scatterplot(centers[:,0], centers[:,1], ax=ax, s=100, color='black');
# Out:
# C:\Users\ivanp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ivanp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
clasificaciones = k_means.predict(df[['alcohol', 'fixed acidity']])

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_subplot()

ax.set_title('Calidad de vinos por cantidad de alcohol  y acides', pad=15)
ax.set_xlabel('Alcohol')
ax.set_ylabel('fixed acidity')

sns.scatterplot(df['alcohol'], df['fixed acidity'], ax=ax, hue=clasificaciones, palette='rainbow');
sns.scatterplot(centers[:,0], centers[:,1], ax=ax, s=100, color='black');

ax.get_legend().remove()
# Out:
# C:\Users\ivanp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ivanp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
k_means.score(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-f668aa0a37ba> in <module>
# ----> 1 k_means.score(x)
#
# NameError: name 'x' is not defined
